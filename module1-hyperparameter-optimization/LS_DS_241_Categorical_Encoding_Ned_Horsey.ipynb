# %% [markdown]
# _Lambda School Data Science — Practicing & Understanding Predictive Modeling_
#
# # Categorical Encoding

# %% [markdown]
# ### [category_encoders](http://contrib.scikit-learn.org/categorical-encoding/)
#
# Install category_encoders, version >= 2.0.0
# - Google Colab: `pip install category_encoders`
# - Local, Anaconda: `conda install -c conda-forge category_encoders`

# %%
import category_encoders as ce
ce.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ### Categorical encoding for trees
# - [Are categorical variables getting lost in your random forests?](https://roamanalytics.com/2016/10/28/are-categorical-variables-getting-lost-in-your-random-forests/)
# - [Beyond One-Hot: An Exploration of Categorical Variables](http://www.willmcginnis.com/2015/11/29/beyond-one-hot-an-exploration-of-categorical-variables/)
# - [Categorical Features and Encoding in Decision Trees](https://medium.com/data-design/visiting-categorical-features-and-encoding-in-decision-trees-53400fa65931)
# - [Coursera — How to Win a Data Science Competition: Learn from Top Kagglers — Concept of mean encoding](https://www.coursera.org/lecture/competitive-data-science/concept-of-mean-encoding-b5Gxv)
# - [Mean (likelihood) encodings: a comprehensive study](https://www.kaggle.com/vprokopev/mean-likelihood-encodings-a-comprehensive-study)
# - [The Mechanics of Machine Learning, Chapter 6: Categorically Speaking](https://mlbook.explained.ai/catvars.html)

# %% [markdown]
# ### Can you predict if peer-to-peer loans are charged off or fully paid?
#
# [Lending Club says,](https://www.lendingclub.com/) _"Our mission is to transform the banking system to make credit more affordable and investing more rewarding."_ You can view their [loan statistics and visualizations](https://www.lendingclub.com/info/demand-and-credit-profile.action).
#
# [According to Wikipedia,](https://en.wikipedia.org/wiki/Lending_Club) _Lending Club is the world's largest peer-to-peer lending platform._
#
# >Lending Club enables borrowers to create unsecured personal loans between $1,000 and 40,000. The standard loan period is three years. Investors can search and browse the loan listings on Lending Club website and select loans that they want to invest in based on the information supplied about the borrower, amount of loan, loan grade, and loan purpose. Investors make money from interest. Lending Club makes money by charging borrowers an origination fee and investors a service fee.

# %% [markdown]
# The data is a stratified sample of 100,000 Lending Club peer-to-peer loans with a loan status of "Charged Off" or "Fully Paid", issued from 2007 through 2018.
#
# The set of variables included here are the intersection of what's available both when investors download historical data and when investors browse loans for manual investing.

# %% [markdown]
# Target: `charged_off`
#
# Data dictionary: https://resources.lendingclub.com/LCDataDictionary.xlsx

# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
url = 'https://drive.google.com/uc?export=download&id=1AafT_i1dmfaxqKiyFofVndleKozbQw3l'
df = pd.read_csv(url)
df.shape
# Out:
# (100000, 104)

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='charged_off')
y = df['charged_off']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.80, test_size=0.20, stratify=y, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((80000, 103), (20000, 103), (80000,), (20000,))

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.80045
# 1    0.19955
# Name: charged_off, dtype: float64

# %%
X_train.describe(include='number').T
# Out:
#                                        count          mean            std  \
# id                                   80000.0  1.667101e+06  384960.937520
# member_id                                0.0           NaN            NaN
# loan_amnt                            80000.0  1.438593e+04    8653.335024
# funded_amnt                          80000.0  1.437877e+04    8649.381479
# installment                          80000.0  4.372868e+02     260.270011
# annual_inc                           80000.0  7.587264e+04   59552.605399
# url                                      0.0           NaN            NaN
# dti                                  79988.0  1.836223e+01      12.294500
# delinq_2yrs                          80000.0  3.147875e-01       0.866750
# inq_last_6mths                       80000.0  6.546125e-01       0.936913
# mths_since_last_delinq               39660.0  3.434501e+01      21.929155
# mths_since_last_record               13622.0  7.083593e+01      26.757617
# open_acc                             80000.0  1.160708e+01       5.461223
# pub_rec                              80000.0  2.137125e-01       0.565591
# revol_bal                            80000.0  1.623509e+04   21544.764197
# total_acc                            80000.0  2.499205e+01      11.945675
# collections_12_mths_ex_med           79997.0  1.587560e-02       0.135643
# mths_since_last_major_derog          21121.0  4.376010e+01      21.346849
# annual_inc_joint                      1452.0  1.183344e+05   59142.189675
# dti_joint                             1452.0  1.892730e+01       7.537044
# acc_now_delinq                       80000.0  5.100000e-03       0.075326
# tot_coll_amt                         75994.0  2.400777e+02    2201.623649
# tot_cur_bal                          75994.0  1.400099e+05  154611.532201
# open_acc_6m                          31574.0  1.046969e+00       1.214302
# open_act_il                          31574.0  2.799392e+00       3.003969
# open_il_12m                          31574.0  7.741496e-01       1.007941
# open_il_24m                          31574.0  1.738677e+00       1.694017
# mths_since_rcnt_il                   30780.0  1.956559e+01      24.456717
# total_bal_il                         31574.0  3.559307e+04   41840.997548
# il_util                              27313.0  7.130030e+01      22.862406
# open_rv_12m                          31574.0  1.416799e+00       1.577092
# open_rv_24m                          31574.0  3.003389e+00       2.714224
# max_bal_bc                           31574.0  5.564733e+03    5671.510196
# all_util                             31572.0  5.813056e+01      20.844126
# total_rev_hi_lim                     75994.0  3.276671e+04   32517.348356
# inq_fi                               31574.0  1.083676e+00       1.579861
# total_cu_tl                          31574.0  1.609362e+00       2.816779
# inq_last_12m                         31574.0  2.294768e+00       2.504900
# acc_open_past_24mths                 77148.0  4.691113e+00       3.194332
# avg_cur_bal                          75993.0  1.340204e+04   16134.238275
# bc_open_to_buy                       76350.0  1.021621e+04   15406.411768
# bc_util                              76305.0  5.995939e+01      28.228322
# chargeoff_within_12_mths             79997.0  9.412853e-03       0.112025
# delinq_amnt                          80000.0  1.490902e+01    1107.085590
# mo_sin_old_il_acct                   73830.0  1.261157e+02      52.186860
# mo_sin_old_rev_tl_op                 75993.0  1.815375e+02      94.283565
# mo_sin_rcnt_rev_tl_op                75993.0  1.315224e+01      16.391837
# mo_sin_rcnt_tl                       75994.0  7.881714e+00       8.800764
# mort_acc                             77148.0  1.662506e+00       1.993026
# mths_since_recent_bc                 76397.0  2.383154e+01      30.989525
# mths_since_recent_bc_dlq             19048.0  3.955386e+01      22.642272
# mths_since_recent_inq                69592.0  6.712582e+00       5.854936
# mths_since_recent_revol_delinq       26823.0  3.579995e+01      22.351797
# num_accts_ever_120_pd                75994.0  5.054083e-01       1.300517
# num_actv_bc_tl                       75994.0  3.645630e+00       2.236697
# num_actv_rev_tl                      75994.0  5.658578e+00       3.302315
# num_bc_sats                          76688.0  4.741850e+00       2.949986
# num_bc_tl                            75994.0  8.114772e+00       4.776316
# num_il_tl                            75994.0  8.557399e+00       7.330757
# num_op_rev_tl                        75994.0  8.286154e+00       4.532487
# num_rev_accts                        75994.0  1.462513e+01       8.082111
# num_rev_tl_bal_gt_0                  75994.0  5.606877e+00       3.216235
# num_sats                             76688.0  1.165078e+01       5.470515
# num_tl_120dpd_2m                     72953.0  7.264951e-04       0.027943
# num_tl_30dpd                         75994.0  3.552912e-03       0.062940
# num_tl_90g_dpd_24m                   75994.0  8.629629e-02       0.487039
# num_tl_op_past_12m                   75994.0  2.177540e+00       1.843496
# pct_tl_nvr_dlq                       75980.0  9.420281e+01       8.695254
# percent_bc_gt_75                     76330.0  4.522486e+01      35.973379
# pub_rec_bankruptcies                 79963.0  1.356002e-01       0.380332
# tax_liens                            79999.0  5.006313e-02       0.344324
# tot_hi_cred_lim                      75994.0  1.732579e+05  172627.965229
# total_bal_ex_mort                    77148.0  4.941473e+04   46002.038954
# total_bc_limit                       77148.0  2.169760e+04   21648.280429
# total_il_high_credit_limit           75994.0  4.196821e+04   42314.131046
# revol_bal_joint                       1028.0  3.116591e+04   26722.770632
# sec_app_inq_last_6mths                1028.0  7.782101e-01       1.084292
# sec_app_mort_acc                      1028.0  1.640078e+00       1.878705
# sec_app_open_acc                      1028.0  1.124611e+01       6.332766
# sec_app_revol_util                    1015.0  5.734975e+01      25.849434
# sec_app_open_act_il                   1028.0  2.873541e+00       3.123794
# sec_app_num_rev_accts                 1028.0  1.281615e+01       8.216416
# sec_app_chargeoff_within_12_mths      1028.0  3.891051e-02       0.242599
# sec_app_collections_12_mths_ex_med    1028.0  8.754864e-02       0.445819
# sec_app_mths_since_last_major_derog    362.0  3.761326e+01      25.377911
#
#                                             min           25%          50%  \
# id                                   1000000.00  1.333199e+06  1667750.500
# member_id                                   NaN           NaN          NaN
# loan_amnt                               1000.00  8.000000e+03    12000.000
# funded_amnt                             1000.00  8.000000e+03    12000.000
# installment                               23.61  2.495400e+02      374.640
# annual_inc                                 0.00  4.576000e+04    65000.000
# url                                         NaN           NaN          NaN
# dti                                        0.00  1.188000e+01       17.635
# delinq_2yrs                                0.00  0.000000e+00        0.000
# inq_last_6mths                             0.00  0.000000e+00        0.000
# mths_since_last_delinq                     0.00  1.600000e+01       31.000
# mths_since_last_record                     0.00  5.300000e+01       72.000
# open_acc                                   0.00  8.000000e+00       11.000
# pub_rec                                    0.00  0.000000e+00        0.000
# revol_bal                                  0.00  6.019000e+03    11209.500
# total_acc                                  2.00  1.600000e+01       23.000
# collections_12_mths_ex_med                 0.00  0.000000e+00        0.000
# mths_since_last_major_derog                0.00  2.700000e+01       44.000
# annual_inc_joint                       26976.00  8.200000e+04   107250.000
# dti_joint                                  0.84  1.343750e+01       18.650
# acc_now_delinq                             0.00  0.000000e+00        0.000
# tot_coll_amt                               0.00  0.000000e+00        0.000
# tot_cur_bal                                0.00  2.947800e+04    80189.000
# open_acc_6m                                0.00  0.000000e+00        1.000
# open_act_il                                0.00  1.000000e+00        2.000
# open_il_12m                                0.00  0.000000e+00        1.000
# open_il_24m                                0.00  1.000000e+00        1.000
# mths_since_rcnt_il                         0.00  6.000000e+00       12.000
# total_bal_il                               0.00  9.633250e+03    24056.000
# il_util                                    0.00  5.800000e+01       74.000
# open_rv_12m                                0.00  0.000000e+00        1.000
# open_rv_24m                                0.00  1.000000e+00        2.000
# max_bal_bc                                 0.00  2.190000e+03     4238.000
# all_util                                   0.00  4.400000e+01       59.000
# total_rev_hi_lim                           0.00  1.420000e+04    24200.000
# inq_fi                                     0.00  0.000000e+00        1.000
# total_cu_tl                                0.00  0.000000e+00        0.000
# inq_last_12m                               0.00  1.000000e+00        2.000
# acc_open_past_24mths                       0.00  2.000000e+00        4.000
# avg_cur_bal                                0.00  3.103000e+03     7349.000
# bc_open_to_buy                             0.00  1.481250e+03     4698.000
# bc_util                                    0.00  3.820000e+01       63.000
# chargeoff_within_12_mths                   0.00  0.000000e+00        0.000
# delinq_amnt                                0.00  0.000000e+00        0.000
# mo_sin_old_il_acct                         1.00  9.800000e+01      129.000
# mo_sin_old_rev_tl_op                       5.00  1.180000e+02      164.000
# mo_sin_rcnt_rev_tl_op                      0.00  4.000000e+00        8.000
# mo_sin_rcnt_tl                             0.00  3.000000e+00        5.000
# mort_acc                                   0.00  0.000000e+00        1.000
# mths_since_recent_bc                       0.00  6.000000e+00       13.000
# mths_since_recent_bc_dlq                   0.00  2.100000e+01       38.000
# mths_since_recent_inq                      0.00  2.000000e+00        5.000
# mths_since_recent_revol_delinq             0.00  1.700000e+01       33.000
# num_accts_ever_120_pd                      0.00  0.000000e+00        0.000
# num_actv_bc_tl                             0.00  2.000000e+00        3.000
# num_actv_rev_tl                            0.00  3.000000e+00        5.000
# num_bc_sats                                0.00  3.000000e+00        4.000
# num_bc_tl                                  0.00  5.000000e+00        7.000
# num_il_tl                                  0.00  4.000000e+00        7.000
# num_op_rev_tl                              0.00  5.000000e+00        7.000
# num_rev_accts                              0.00  9.000000e+00       13.000
# num_rev_tl_bal_gt_0                        0.00  3.000000e+00        5.000
# num_sats                                   0.00  8.000000e+00       11.000
# num_tl_120dpd_2m                           0.00  0.000000e+00        0.000
# num_tl_30dpd                               0.00  0.000000e+00        0.000
# num_tl_90g_dpd_24m                         0.00  0.000000e+00        0.000
# num_tl_op_past_12m                         0.00  1.000000e+00        2.000
# pct_tl_nvr_dlq                             0.00  9.140000e+01       97.900
# percent_bc_gt_75                           0.00  1.110000e+01       42.900
# pub_rec_bankruptcies                       0.00  0.000000e+00        0.000
# tax_liens                                  0.00  0.000000e+00        0.000
# tot_hi_cred_lim                            0.00  4.994300e+04   112263.500
# total_bal_ex_mort                          0.00  2.098600e+04    37198.000
# total_bc_limit                             0.00  7.800000e+03    15100.000
# total_il_high_credit_limit                 0.00  1.489175e+04    31742.500
# revol_bal_joint                          290.00  1.366100e+04    24585.000
# sec_app_inq_last_6mths                     0.00  0.000000e+00        0.000
# sec_app_mort_acc                           0.00  0.000000e+00        1.000
# sec_app_open_acc                           0.00  7.000000e+00       10.000
# sec_app_revol_util                         0.00  3.880000e+01       58.500
# sec_app_open_act_il                        0.00  1.000000e+00        2.000
# sec_app_num_rev_accts                      0.00  7.000000e+00       11.000
# sec_app_chargeoff_within_12_mths           0.00  0.000000e+00        0.000
# sec_app_collections_12_mths_ex_med         0.00  0.000000e+00        0.000
# sec_app_mths_since_last_major_derog        0.00  1.400000e+01       36.000
#
#                                              75%         max
# id                                   1998223.000  2336172.00
# member_id                                    NaN         NaN
# loan_amnt                              20000.000    40000.00
# funded_amnt                            20000.000    40000.00
# installment                              578.265     1566.80
# annual_inc                             90000.000  6000000.00
# url                                          NaN         NaN
# dti                                       24.120      999.00
# delinq_2yrs                                0.000       20.00
# inq_last_6mths                             1.000        7.00
# mths_since_last_delinq                    50.000      226.00
# mths_since_last_record                    91.000      119.00
# open_acc                                  14.000       71.00
# pub_rec                                    0.000       13.00
# revol_bal                              19808.000   898146.00
# total_acc                                 32.000      176.00
# collections_12_mths_ex_med                 0.000        4.00
# mths_since_last_major_derog               61.000      226.00
# annual_inc_joint                      140737.500   642000.00
# dti_joint                                 23.950       69.49
# acc_now_delinq                             0.000        3.00
# tot_coll_amt                               0.000   309838.00
# tot_cur_bal                           208341.250  5172185.00
# open_acc_6m                                2.000       15.00
# open_act_il                                3.000       37.00
# open_il_12m                                1.000       20.00
# open_il_24m                                2.000       30.00
# mths_since_rcnt_il                        22.000      411.00
# total_bal_il                           46601.000   706085.00
# il_util                                   87.000      291.00
# open_rv_12m                                2.000       20.00
# open_rv_24m                                4.000       43.00
# max_bal_bc                              7189.000   361299.00
# all_util                                  73.000      198.00
# total_rev_hi_lim                       40700.000   914900.00
# inq_fi                                     2.000       24.00
# total_cu_tl                                2.000       45.00
# inq_last_12m                               3.000       36.00
# acc_open_past_24mths                       6.000       49.00
# avg_cur_bal                            18588.000   445856.00
# bc_open_to_buy                         12387.000   292422.00
# bc_util                                   84.900      183.60
# chargeoff_within_12_mths                   0.000        7.00
# delinq_amnt                                0.000   249925.00
# mo_sin_old_il_acct                       153.000      549.00
# mo_sin_old_rev_tl_op                     229.000      803.00
# mo_sin_rcnt_rev_tl_op                     16.000      324.00
# mo_sin_rcnt_tl                            10.000      174.00
# mort_acc                                   3.000       34.00
# mths_since_recent_bc                      28.000      639.00
# mths_since_recent_bc_dlq                  58.000      158.00
# mths_since_recent_inq                     10.000       25.00
# mths_since_recent_revol_delinq            52.000      158.00
# num_accts_ever_120_pd                      0.000       28.00
# num_actv_bc_tl                             5.000       32.00
# num_actv_rev_tl                            7.000       41.00
# num_bc_sats                                6.000       48.00
# num_bc_tl                                 11.000       66.00
# num_il_tl                                 11.000      121.00
# num_op_rev_tl                             10.000       61.00
# num_rev_accts                             19.000       94.00
# num_rev_tl_bal_gt_0                        7.000       35.00
# num_sats                                  14.000       71.00
# num_tl_120dpd_2m                           0.000        2.00
# num_tl_30dpd                               0.000        2.00
# num_tl_90g_dpd_24m                         0.000       18.00
# num_tl_op_past_12m                         3.000       28.00
# pct_tl_nvr_dlq                           100.000      100.00
# percent_bc_gt_75                          75.000      100.00
# pub_rec_bankruptcies                       0.000        7.00
# tax_liens                                  0.000       12.00
# tot_hi_cred_lim                       250738.000  5369659.00
# total_bal_ex_mort                      62519.000   857028.00
# total_bc_limit                         28100.000   470900.00
# total_il_high_credit_limit             56441.750   954503.00
# revol_bal_joint                        39759.000   357135.00
# sec_app_inq_last_6mths                     1.000        6.00
# sec_app_mort_acc                           3.000       11.00
# sec_app_open_acc                          15.000       37.00
# sec_app_revol_util                        77.750      132.30
# sec_app_open_act_il                        4.000       24.00
# sec_app_num_rev_accts                     17.000       56.00
# sec_app_chargeoff_within_12_mths           0.000        4.00
# sec_app_collections_12_mths_ex_med         0.000        8.00
# sec_app_mths_since_last_major_derog       60.000      105.00

# %%
X_train.describe(exclude='number').T.sort_values(by='unique')
# Out:
#                           count unique                 top   freq
# term                      80000      2           36 months  60781
# application_type          80000      2          Individual  78548
# initial_list_status       80000      2                   w  46513
# disbursement_method       80000      2                Cash  79612
# home_ownership            80000      6            MORTGAGE  39614
# grade                     80000      7                   B  23583
# emp_length                75387     11           10+ years  26395
# purpose                   80000     14  debt_consolidation  46509
# sub_grade                 80000     35                  C1   5049
# addr_state                80000     50                  CA  11523
# sec_app_earliest_cr_line   1028    334            Aug-2006     17
# int_rate                  80000    561              10.99%   2376
# earliest_cr_line          80000    635            Aug-2001    569
# zip_code                  80000    875               945xx    895
# revol_util                79946   1089                  0%    385
# title                     79017   5553  Debt consolidation  39386
# desc                       7357   7333                         16
# emp_title                 74928  36658             Teacher   1285

# %% [markdown]
# ## Categorical exploration, 1 feature at a time
#
# Change `feature`, then re-run these cells!

# %%
feature = 'initial_list_status'

# %%
X_train[feature].value_counts()
# Out:
# w    46513
# f    33487
# Name: initial_list_status, dtype: int64

# %%
X_train[[feature]].head()
# Out:
#       initial_list_status
# 25539                   w
# 28968                   w
# 34666                   f
# 20864                   w
# 75088                   w

# %% [markdown]
# ### One Hot Encoding
#
# Warning: May run slow, or run out of memory, with high cardinality categoricals!

# %%
encoder = ce.OneHotEncoder(use_cat_names=True)
encoded = encoder.fit_transform(X_train[[feature]])
print(f'{len(encoded.columns)} columns')
encoded.head()
# Out:
# 14 columns
#        purpose_debt_consolidation  purpose_credit_card  \
# 25539                           1                    0
# 28968                           0                    1
# 34666                           0                    0
# 20864                           1                    0
# 75088                           0                    0
#
#        purpose_home_improvement  purpose_major_purchase  purpose_moving  \
# 25539                         0                       0               0
# 28968                         0                       0               0
# 34666                         1                       0               0
# 20864                         0                       0               0
# 75088                         1                       0               0
#
#        purpose_house  purpose_other  purpose_renewable_energy  \
# 25539              0              0                         0
# 28968              0              0                         0
# 34666              0              0                         0
# 20864              0              0                         0
# 75088              0              0                         0
#
#        purpose_wedding  purpose_vacation  purpose_small_business  purpose_car  \
# 25539                0                 0                       0            0
# 28968                0                 0                       0            0
# 34666                0                 0                       0            0
# 20864                0                 0                       0            0
# 75088                0                 0                       0            0
#
#        purpose_medical  purpose_educational
# 25539                0                    0
# 28968                0                    0
# 34666                0                    0
# 20864                0                    0
# 75088                0                    0

# %% [markdown]
# ### Binary Encoding

# %%
encoder = ce.BinaryEncoder()
encoded = encoder.fit_transform(X_train[[feature]])
print(f'{len(encoded.columns)} columns')
encoded.head()
# Out:
# 2 columns
#        initial_list_status_0  initial_list_status_1
# 25539                      0                      1
# 28968                      0                      1
# 34666                      1                      0
# 20864                      0                      1
# 75088                      0                      1

# %%
2**7
# Out:
# 128

# %%
import math
math.sqrt(50)
# Out:
# 7.0710678118654755

# %% [markdown]
# ### "Ordinal" Encoding

# %%
encoder = ce.OrdinalEncoder()
encoded = encoder.fit_transform(X_train[[feature]])
print(f'1 column, {encoded[feature].nunique()} unique values')
encoded.head()
# Out:
# 1 column, 2 unique values
#        initial_list_status
# 25539                    1
# 28968                    1
# 34666                    2
# 20864                    1
# 75088                    1

# %% [markdown]
# ### Target (Mean) Encoding
#
# Warning: May overfit!

# %%
first5 = X_train[feature].head().values
train = pd.concat([X_train, y_train], axis='columns')
target_mean = train.groupby(feature)['charged_off'].mean()
target_mean[first5]
# Out:
# home_ownership
# MORTGAGE    0.172490
# MORTGAGE    0.172490
# MORTGAGE    0.172490
# MORTGAGE    0.172490
# RENT        0.233511
# Name: charged_off, dtype: float64

# %%
min_samples_leaf = 10
encoder = ce.TargetEncoder(min_samples_leaf=min_samples_leaf)
encoded = encoder.fit_transform(X_train[[feature]], y_train)
print(f'1 column, {encoded[feature].nunique()} unique values, min_samples_leaf={min_samples_leaf}')
encoded.head()
# Out:
# 1 column, 6 unique values, min_samples_leaf=10
#        home_ownership
# 25539        0.172490
# 28968        0.172490
# 34666        0.172490
# 20864        0.172490
# 75088        0.233511

# %%
min_samples_leaf = 100
encoder = ce.TargetEncoder(min_samples_leaf=min_samples_leaf)
encoded = encoder.fit_transform(X_train[[feature]], y_train)
print(f'1 column, {encoded[feature].nunique()} unique values, min_samples_leaf={min_samples_leaf}')
encoded.head()
# Out:
# 1 column, 2 unique values, min_samples_leaf=100
#        application_type
# 25539          0.198643
# 28968          0.198643
# 34666          0.198643
# 20864          0.198643
# 75088          0.198643

# %%
min_samples_leaf = 1000
encoder = ce.TargetEncoder(min_samples_leaf=min_samples_leaf)
encoded = encoder.fit_transform(X_train[[feature]], y_train)
print(f'1 column, {encoded[feature].nunique()} unique values, min_samples_leaf={min_samples_leaf}')
encoded.head()
# Out:
# 1 column, 2 unique values, min_samples_leaf=1000
#        application_type
# 25539          0.198643
# 28968          0.198643
# 34666          0.198643
# 20864          0.198643
# 75088          0.198643

# %% [markdown]
# ### BONUS: Data Wrangling / Feature Engineering Example

# %%
X = df.drop(columns='charged_off')
y = df['charged_off']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.80, test_size=0.20, stratify=y, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((80000, 103), (20000, 103), (80000,), (20000,))

# %%
def wrangle(X):
    X = X.copy()
    
    # Drop some columns
    X = X.drop(columns='id')  # id is random
    X = X.drop(columns=['member_id', 'url', 'desc'])  # All null
    X = X.drop(columns='title')  # Duplicative of purpose
    X = X.drop(columns='grade')  # Duplicative of sub_grade
    
    # Transform sub_grade from "A1" - "G5" to 1.1 - 7.5
    def wrangle_sub_grade(x):
        first_digit = ord(x[0]) - 64
        second_digit = int(x[1])
        return first_digit + second_digit/10
    
    X['sub_grade'] = X['sub_grade'].apply(wrangle_sub_grade)

    # Convert percentages from strings to floats
    X['int_rate'] = X['int_rate'].str.strip('%').astype(float)
    X['revol_util'] = X['revol_util'].str.strip('%').astype(float)
        
    # Transform earliest_cr_line to an integer: how many days it's been open
    X['earliest_cr_line'] = pd.to_datetime(X['earliest_cr_line'], infer_datetime_format=True)
    X['earliest_cr_line'] = pd.Timestamp.today() - X['earliest_cr_line']
    X['earliest_cr_line'] = X['earliest_cr_line'].dt.days
    
    # Create features for three employee titles: teacher, manager, owner
    X['emp_title'] = X['emp_title'].str.lower()
    X['emp_title_teacher'] = X['emp_title'].str.contains('teacher', na=False)
    X['emp_title_manager'] = X['emp_title'].str.contains('manager', na=False)
    X['emp_title_owner']   = X['emp_title'].str.contains('owner', na=False)
    
    # Drop categoricals with highest cardinality
    X = X.drop(columns=['emp_title', 'zip_code'])
    
    #encode categoricals as Binary ecoders
    X['application_type'] = ce.BinaryEncoder().fit_transform(X['application_type'])
    X['disbursement_method'] = ce.BinaryEncoder().fit_transform(X['disbursement_method'])
    X['home_ownership']= ce.BinaryEncoder().fit_transform(X['home_ownership'])
    X['initial_list_status']= ce.BinaryEncoder().fit_transform(X['initial_list_status'])
    X['purpose'] = ce.BinaryEncoder().fit_transform(X['purpose'])
    X['addr_state'] = ce.BinaryEncoder().fit_transform(X['purpose'])

    
    #convert to simple int
    X['term'] = X['term'].str.strip(' months').astype(np.int8)
    
    # Transform features with many nulls to binary flags
    many_nulls = ['sec_app_mths_since_last_major_derog',
                  'sec_app_revol_util',
                  'sec_app_earliest_cr_line',
                  'sec_app_mort_acc',
                  'dti_joint',
                  'sec_app_collections_12_mths_ex_med',
                  'sec_app_chargeoff_within_12_mths',
                  'sec_app_num_rev_accts',
                  'sec_app_open_act_il',
                  'sec_app_open_acc',
                  'revol_bal_joint',
                  'annual_inc_joint',
                  'sec_app_inq_last_6mths',
                  'mths_since_last_record',
                  'mths_since_recent_bc_dlq',
                  'mths_since_last_major_derog',
                  'mths_since_recent_revol_delinq',
                  'mths_since_last_delinq',
                  'il_util',
                  'emp_length',
                  'mths_since_recent_inq',
                  'mo_sin_old_il_acct',
                  'mths_since_rcnt_il',
                  'num_tl_120dpd_2m',
                  'bc_util',
                  'percent_bc_gt_75',
                  'bc_open_to_buy',
                  'mths_since_recent_bc']

    for col in many_nulls:
        X[col] = X[col].isnull()
    
    # For features with few nulls, do mean imputation
    for col in X:
        if X[col].isnull().sum() > 0:
            X[col] = X[col].fillna(X[col].mean())
    
    # Return the wrangled dataframe
    return X

# wrangle data
X_train = wrangle(X_train)
X_test  = wrangle(X_test)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((80000, 98), (20000, 98), (80000,), (20000,))

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_auc_score


params= {
    'learning_rate' : [.03, .07],
    #'nthread':[4],
    'n_estimators': [50, 100, 150],
    'max_depth': [2, 4, 6],
    'booster': [ 'dart', 'gbtree', 'gblinear']
}

gridsearch = RandomizedSearchCV(
    XGBClassifier(seed=42), #tree_method='gpu_hist'
    param_distributions = params,
    scoring='roc_auc',
    n_iter = 10,
    cv=5,
    n_jobs = -1,
    verbose=10,
    random_state=42,
    return_train_score=True
)

gridsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   13.6s
# /home/nedderlander/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  3.8min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42, silent=True,
#        subsample=1),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=-1,
#           param_distributions={'learning_rate': [0.03, 0.07], 'n_estimators': [50, 100, 150], 'max_depth': [2, 4, 6], 'booster': ['dart', 'gbtree', 'gblinear']},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score=True, scoring='roc_auc', verbose=10)

# %%
results = pd.DataFrame(gridsearch.cv_results_)
results.sort_values(by='rank_test_score').T

y_pred_proba = gridsearch.best_estimator_.predict_proba(X_test)[:,1]
test_roc = roc_auc_score(y_test, y_pred_proba)

gridsearch.best_estimator_, test_roc
# Out:
# (XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#         colsample_bytree=1, gamma=0, learning_rate=0.07, max_delta_step=0,
#         max_depth=4, min_child_weight=1, missing=None, n_estimators=150,
#         n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#         reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42, silent=True,
#         subsample=1), 0.715281231418327)

# %%
results.sort_values(by='rank_test_score').T
# Out:
#                                                                      9  \
# mean_fit_time                                                  21.5238
# std_fit_time                                                  0.462933
# mean_score_time                                               0.180764
# std_score_time                                              0.00654401
# param_n_estimators                                                 150
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                   gbtree
# params               {'n_estimators': 150, 'max_depth': 4, 'learnin...
# split0_test_score                                             0.726777
# split1_test_score                                             0.726976
# split2_test_score                                             0.722351
# split3_test_score                                             0.711628
# split4_test_score                                             0.721437
# mean_test_score                                               0.721834
# std_test_score                                              0.00557611
# rank_test_score                                                      1
# split0_train_score                                            0.752401
# split1_train_score                                            0.752374
# split2_train_score                                            0.753954
# split3_train_score                                            0.754892
# split4_train_score                                            0.754641
# mean_train_score                                              0.753653
# std_train_score                                             0.00107742
#
#                                                                      6  \
# mean_fit_time                                                  66.0383
# std_fit_time                                                  0.920468
# mean_score_time                                                0.20856
# std_score_time                                              0.00526414
# param_n_estimators                                                 150
# param_max_depth                                                      6
# param_learning_rate                                               0.07
# param_booster                                                     dart
# params               {'n_estimators': 150, 'max_depth': 6, 'learnin...
# split0_test_score                                             0.725816
# split1_test_score                                              0.72449
# split2_test_score                                             0.721447
# split3_test_score                                               0.7115
# split4_test_score                                             0.719373
# mean_test_score                                               0.720526
# std_test_score                                              0.00504679
# rank_test_score                                                      2
# split0_train_score                                            0.806774
# split1_train_score                                            0.806517
# split2_train_score                                            0.812813
# split3_train_score                                            0.808421
# split4_train_score                                            0.808089
# mean_train_score                                              0.808523
# std_train_score                                              0.0022663
#
#                                                                      5  \
# mean_fit_time                                                  39.5392
# std_fit_time                                                  0.472999
# mean_score_time                                               0.160704
# std_score_time                                              0.00497458
# param_n_estimators                                                 150
# param_max_depth                                                      4
# param_learning_rate                                               0.03
# param_booster                                                     dart
# params               {'n_estimators': 150, 'max_depth': 4, 'learnin...
# split0_test_score                                             0.723321
# split1_test_score                                             0.722401
# split2_test_score                                             0.718091
# split3_test_score                                             0.708838
# split4_test_score                                             0.716859
# mean_test_score                                               0.717902
# std_test_score                                              0.00515518
# rank_test_score                                                      3
# split0_train_score                                            0.732939
# split1_train_score                                            0.732473
# split2_train_score                                            0.733885
# split3_train_score                                            0.736326
# split4_train_score                                            0.733627
# mean_train_score                                               0.73385
# std_train_score                                             0.00133494
#
#                                                                      3  \
# mean_fit_time                                                   9.4237
# std_fit_time                                                  0.200286
# mean_score_time                                               0.115912
# std_score_time                                              0.00562023
# param_n_estimators                                                  50
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                     dart
# params               {'n_estimators': 50, 'max_depth': 4, 'learning...
# split0_test_score                                             0.720956
# split1_test_score                                             0.719741
# split2_test_score                                             0.715433
# split3_test_score                                             0.705581
# split4_test_score                                              0.71436
# mean_test_score                                               0.715214
# std_test_score                                              0.00542313
# rank_test_score                                                      4
# split0_train_score                                            0.726882
# split1_train_score                                            0.726865
# split2_train_score                                             0.72818
# split3_train_score                                            0.730067
# split4_train_score                                            0.727712
# mean_train_score                                              0.727941
# std_train_score                                             0.00117515
#
#                                                                      8  \
# mean_fit_time                                                  8.77855
# std_fit_time                                                 0.0544124
# mean_score_time                                               0.106513
# std_score_time                                              0.00346978
# param_n_estimators                                                  50
# param_max_depth                                                      4
# param_learning_rate                                               0.03
# param_booster                                                     dart
# params               {'n_estimators': 50, 'max_depth': 4, 'learning...
# split0_test_score                                             0.714437
# split1_test_score                                             0.712277
# split2_test_score                                             0.709484
# split3_test_score                                             0.699625
# split4_test_score                                             0.707366
# mean_test_score                                               0.708638
# std_test_score                                              0.00510775
# rank_test_score                                                      5
# split0_train_score                                            0.714761
# split1_train_score                                            0.714712
# split2_train_score                                            0.716177
# split3_train_score                                            0.718286
# split4_train_score                                            0.715554
# mean_train_score                                              0.715898
# std_train_score                                             0.00131124
#
#                                                                      0  \
# mean_fit_time                                                  8.17585
# std_fit_time                                                  0.151241
# mean_score_time                                               0.118986
# std_score_time                                              0.00633256
# param_n_estimators                                                 100
# param_max_depth                                                      2
# param_learning_rate                                               0.03
# param_booster                                                   gbtree
# params               {'n_estimators': 100, 'max_depth': 2, 'learnin...
# split0_test_score                                             0.712012
# split1_test_score                                             0.709731
# split2_test_score                                             0.706173
# split3_test_score                                             0.697143
# split4_test_score                                             0.703143
# mean_test_score                                               0.705641
# std_test_score                                              0.00521634
# rank_test_score                                                      6
# split0_train_score                                            0.706857
# split1_train_score                                            0.706886
# split2_train_score                                             0.70745
# split3_train_score                                            0.709488
# split4_train_score                                            0.708094
# mean_train_score                                              0.707755
# std_train_score                                            0.000977104
#
#                                                                      1  \
# mean_fit_time                                                  3.57142
# std_fit_time                                                  0.109109
# mean_score_time                                               0.106241
# std_score_time                                              0.00766825
# param_n_estimators                                                 100
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                 gblinear
# params               {'n_estimators': 100, 'max_depth': 4, 'learnin...
# split0_test_score                                             0.689554
# split1_test_score                                             0.679862
# split2_test_score                                             0.684151
# split3_test_score                                             0.673895
# split4_test_score                                              0.67629
# mean_test_score                                                0.68075
# std_test_score                                              0.00559917
# rank_test_score                                                      7
# split0_train_score                                            0.679642
# split1_train_score                                            0.681359
# split2_train_score                                            0.680821
# split3_train_score                                            0.683493
# split4_train_score                                             0.68285
# mean_train_score                                              0.681633
# std_train_score                                             0.00138854
#
#                                                                      7  \
# mean_fit_time                                                  3.19616
# std_fit_time                                                 0.0477271
# mean_score_time                                              0.0930955
# std_score_time                                             0.000787299
# param_n_estimators                                                 100
# param_max_depth                                                      6
# param_learning_rate                                               0.07
# param_booster                                                 gblinear
# params               {'n_estimators': 100, 'max_depth': 6, 'learnin...
# split0_test_score                                             0.689554
# split1_test_score                                             0.679862
# split2_test_score                                             0.684151
# split3_test_score                                             0.673895
# split4_test_score                                              0.67629
# mean_test_score                                                0.68075
# std_test_score                                              0.00559917
# rank_test_score                                                      7
# split0_train_score                                            0.679642
# split1_train_score                                            0.681359
# split2_train_score                                            0.680821
# split3_train_score                                            0.683493
# split4_train_score                                             0.68285
# mean_train_score                                              0.681633
# std_train_score                                             0.00138854
#
#                                                                      4  \
# mean_fit_time                                                  4.62755
# std_fit_time                                                  0.017849
# mean_score_time                                              0.0961848
# std_score_time                                               0.0015477
# param_n_estimators                                                 150
# param_max_depth                                                      6
# param_learning_rate                                               0.03
# param_booster                                                 gblinear
# params               {'n_estimators': 150, 'max_depth': 6, 'learnin...
# split0_test_score                                             0.680788
# split1_test_score                                             0.669453
# split2_test_score                                             0.675732
# split3_test_score                                              0.66542
# split4_test_score                                             0.667305
# mean_test_score                                                0.67174
# std_test_score                                              0.00570357
# rank_test_score                                                      9
# split0_train_score                                            0.670487
# split1_train_score                                             0.67258
# split2_train_score                                            0.671646
# split3_train_score                                            0.674437
# split4_train_score                                            0.673734
# mean_train_score                                              0.672577
# std_train_score                                             0.00141681
#
#                                                                      2
# mean_fit_time                                                  2.17603
# std_fit_time                                                   0.14956
# mean_score_time                                               0.104358
# std_score_time                                              0.00693722
# param_n_estimators                                                  50
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                 gblinear
# params               {'n_estimators': 50, 'max_depth': 4, 'learning...
# split0_test_score                                             0.675465
# split1_test_score                                             0.662665
# split2_test_score                                              0.66999
# split3_test_score                                             0.659446
# split4_test_score                                             0.661346
# mean_test_score                                               0.665782
# std_test_score                                              0.00601683
# rank_test_score                                                     10
# split0_train_score                                            0.664388
# split1_train_score                                            0.666751
# split2_train_score                                            0.665636
# split3_train_score                                            0.668504
# split4_train_score                                            0.667723
# mean_train_score                                                0.6666
# std_train_score                                             0.00146504

# %%
# remove gblinear, focus on more esimators / deeper
params= {
    'learning_rate' : [.03, .07],
    #'nthread':[4],
    'n_estimators': [150, 200, 250],
    'max_depth': [4, 5, 6, 7],
    'booster': [ 'dart', 'gbtree']
}

gridsearch = RandomizedSearchCV(
    XGBClassifier(seed=42, tree_method='gpu_exact', n_jobs=-1), 
    param_distributions = params,
    scoring='roc_auc',
    n_iter = 10,
    cv=5,
    n_jobs = -1,
    verbose=10,
    random_state=42,
    return_train_score=True
)

gridsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# /home/nedderlander/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  5.4min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=42, silent=True, subsample=1, tree_method='gpu_exact'),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=-1,
#           param_distributions={'learning_rate': [0.03, 0.07], 'n_estimators': [150, 200, 250], 'max_depth': [4, 5, 6, 7], 'booster': ['dart', 'gbtree']},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score=True, scoring='roc_auc', verbose=10)

# %%
results.sort_values(by='rank_test_score').T
# Out:
#                                                                      9  \
# mean_fit_time                                                  22.0957
# std_fit_time                                                  0.642369
# mean_score_time                                               0.182406
# std_score_time                                               0.0111649
# param_n_estimators                                                 150
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                   gbtree
# params               {'n_estimators': 150, 'max_depth': 4, 'learnin...
# split0_test_score                                             0.727838
# split1_test_score                                             0.728113
# split2_test_score                                             0.723339
# split3_test_score                                             0.712573
# split4_test_score                                             0.721702
# mean_test_score                                               0.722713
# std_test_score                                              0.00565087
# rank_test_score                                                      1
# split0_train_score                                            0.753031
# split1_train_score                                             0.75307
# split2_train_score                                            0.754786
# split3_train_score                                            0.755665
# split4_train_score                                            0.754986
# mean_train_score                                              0.754307
# std_train_score                                             0.00106702
#
#                                                                      6  \
# mean_fit_time                                                  67.3448
# std_fit_time                                                  0.675683
# mean_score_time                                               0.205002
# std_score_time                                              0.00316888
# param_n_estimators                                                 150
# param_max_depth                                                      6
# param_learning_rate                                               0.07
# param_booster                                                     dart
# params               {'n_estimators': 150, 'max_depth': 6, 'learnin...
# split0_test_score                                             0.726744
# split1_test_score                                             0.726022
# split2_test_score                                              0.72238
# split3_test_score                                             0.711777
# split4_test_score                                             0.720001
# mean_test_score                                               0.721385
# std_test_score                                              0.00539356
# rank_test_score                                                      2
# split0_train_score                                            0.808777
# split1_train_score                                            0.809865
# split2_train_score                                             0.81379
# split3_train_score                                             0.81097
# split4_train_score                                            0.809429
# mean_train_score                                              0.810566
# std_train_score                                             0.00176305
#
#                                                                      5  \
# mean_fit_time                                                  40.9571
# std_fit_time                                                  0.686521
# mean_score_time                                               0.169517
# std_score_time                                               0.0055635
# param_n_estimators                                                 150
# param_max_depth                                                      4
# param_learning_rate                                               0.03
# param_booster                                                     dart
# params               {'n_estimators': 150, 'max_depth': 4, 'learnin...
# split0_test_score                                             0.723806
# split1_test_score                                             0.723208
# split2_test_score                                              0.71794
# split3_test_score                                             0.708845
# split4_test_score                                             0.717252
# mean_test_score                                                0.71821
# std_test_score                                               0.0053852
# rank_test_score                                                      3
# split0_train_score                                             0.73313
# split1_train_score                                            0.732787
# split2_train_score                                            0.734511
# split3_train_score                                            0.736608
# split4_train_score                                             0.73416
# mean_train_score                                              0.734239
# std_train_score                                             0.00134402
#
#                                                                      3  \
# mean_fit_time                                                  9.91946
# std_fit_time                                                  0.257899
# mean_score_time                                               0.113825
# std_score_time                                              0.00424181
# param_n_estimators                                                  50
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                     dart
# params               {'n_estimators': 50, 'max_depth': 4, 'learning...
# split0_test_score                                             0.721425
# split1_test_score                                             0.720217
# split2_test_score                                             0.715832
# split3_test_score                                             0.706109
# split4_test_score                                             0.714734
# mean_test_score                                               0.715664
# std_test_score                                              0.00540576
# rank_test_score                                                      4
# split0_train_score                                            0.727218
# split1_train_score                                            0.726816
# split2_train_score                                            0.728395
# split3_train_score                                            0.730798
# split4_train_score                                            0.728046
# mean_train_score                                              0.728255
# std_train_score                                             0.00139087
#
#                                                                      8  \
# mean_fit_time                                                  9.11618
# std_fit_time                                                  0.288283
# mean_score_time                                               0.106513
# std_score_time                                              0.00256035
# param_n_estimators                                                  50
# param_max_depth                                                      4
# param_learning_rate                                               0.03
# param_booster                                                     dart
# params               {'n_estimators': 50, 'max_depth': 4, 'learning...
# split0_test_score                                             0.714573
# split1_test_score                                              0.71273
# split2_test_score                                             0.709445
# split3_test_score                                             0.699871
# split4_test_score                                             0.707512
# mean_test_score                                               0.708826
# std_test_score                                              0.00511015
# rank_test_score                                                      5
# split0_train_score                                            0.714907
# split1_train_score                                            0.715056
# split2_train_score                                            0.716351
# split3_train_score                                             0.71842
# split4_train_score                                            0.715928
# mean_train_score                                              0.716132
# std_train_score                                             0.00126356
#
#                                                                      0  \
# mean_fit_time                                                  8.24537
# std_fit_time                                                  0.252675
# mean_score_time                                               0.121191
# std_score_time                                              0.00393897
# param_n_estimators                                                 100
# param_max_depth                                                      2
# param_learning_rate                                               0.03
# param_booster                                                   gbtree
# params               {'n_estimators': 100, 'max_depth': 2, 'learnin...
# split0_test_score                                             0.712102
# split1_test_score                                             0.709897
# split2_test_score                                             0.706599
# split3_test_score                                             0.697407
# split4_test_score                                              0.70321
# mean_test_score                                               0.705843
# std_test_score                                              0.00518236
# rank_test_score                                                      6
# split0_train_score                                            0.706918
# split1_train_score                                            0.707097
# split2_train_score                                            0.707755
# split3_train_score                                            0.709749
# split4_train_score                                            0.708259
# mean_train_score                                              0.707956
# std_train_score                                             0.00101596
#
#                                                                      1  \
# mean_fit_time                                                  3.53236
# std_fit_time                                                  0.128728
# mean_score_time                                               0.110046
# std_score_time                                               0.0133416
# param_n_estimators                                                 100
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                 gblinear
# params               {'n_estimators': 100, 'max_depth': 4, 'learnin...
# split0_test_score                                             0.690138
# split1_test_score                                             0.680424
# split2_test_score                                             0.684863
# split3_test_score                                             0.674317
# split4_test_score                                             0.676823
# mean_test_score                                               0.681313
# std_test_score                                              0.00566337
# rank_test_score                                                      7
# split0_train_score                                            0.680211
# split1_train_score                                            0.681917
# split2_train_score                                            0.681346
# split3_train_score                                            0.684101
# split4_train_score                                            0.683429
# mean_train_score                                              0.682201
# std_train_score                                             0.00140653
#
#                                                                      7  \
# mean_fit_time                                                  3.31123
# std_fit_time                                                 0.0817902
# mean_score_time                                              0.0955479
# std_score_time                                              0.00677632
# param_n_estimators                                                 100
# param_max_depth                                                      6
# param_learning_rate                                               0.07
# param_booster                                                 gblinear
# params               {'n_estimators': 100, 'max_depth': 6, 'learnin...
# split0_test_score                                             0.690138
# split1_test_score                                             0.680424
# split2_test_score                                             0.684863
# split3_test_score                                             0.674317
# split4_test_score                                             0.676823
# mean_test_score                                               0.681313
# std_test_score                                              0.00566337
# rank_test_score                                                      7
# split0_train_score                                            0.680211
# split1_train_score                                            0.681917
# split2_train_score                                            0.681346
# split3_train_score                                            0.684101
# split4_train_score                                            0.683429
# mean_train_score                                              0.682201
# std_train_score                                             0.00140653
#
#                                                                      4  \
# mean_fit_time                                                  4.87569
# std_fit_time                                                  0.228474
# mean_score_time                                              0.0953442
# std_score_time                                              0.00444275
# param_n_estimators                                                 150
# param_max_depth                                                      6
# param_learning_rate                                               0.03
# param_booster                                                 gblinear
# params               {'n_estimators': 150, 'max_depth': 6, 'learnin...
# split0_test_score                                             0.681808
# split1_test_score                                             0.670514
# split2_test_score                                             0.676936
# split3_test_score                                             0.666231
# split4_test_score                                             0.668301
# mean_test_score                                               0.672758
# std_test_score                                              0.00577676
# rank_test_score                                                      9
# split0_train_score                                            0.671533
# split1_train_score                                            0.673581
# split2_train_score                                            0.672608
# split3_train_score                                            0.675509
# split4_train_score                                            0.674786
# mean_train_score                                              0.673603
# std_train_score                                             0.00143576
#
#                                                                      2
# mean_fit_time                                                   1.9991
# std_fit_time                                                 0.0796813
# mean_score_time                                               0.096084
# std_score_time                                               0.0044957
# param_n_estimators                                                  50
# param_max_depth                                                      4
# param_learning_rate                                               0.07
# param_booster                                                 gblinear
# params               {'n_estimators': 50, 'max_depth': 4, 'learning...
# split0_test_score                                             0.676796
# split1_test_score                                             0.664042
# split2_test_score                                             0.671593
# split3_test_score                                             0.660539
# split4_test_score                                             0.662612
# mean_test_score                                               0.667117
# std_test_score                                              0.00611109
# rank_test_score                                                     10
# split0_train_score                                            0.665767
# split1_train_score                                            0.668064
# split2_train_score                                            0.666905
# split3_train_score                                            0.669899
# split4_train_score                                             0.66911
# mean_train_score                                              0.667949
# std_train_score                                             0.00148434

# %%
results = pd.DataFrame(gridsearch.cv_results_)
results.sort_values(by='rank_test_score').T

y_pred_proba = gridsearch.best_estimator_.predict_proba(X_test)[:,1]
test_roc = roc_auc_score(y_test, y_pred_proba)

gridsearch.best_estimator_, test_roc
# Out:
# (XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#         colsample_bytree=1, gamma=0, learning_rate=0.07, max_delta_step=0,
#         max_depth=4, min_child_weight=1, missing=None, n_estimators=200,
#         n_jobs=-1, nthread=None, objective='binary:logistic',
#         random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#         seed=42, silent=True, subsample=1, tree_method='gpu_exact'),
#  0.712043020651798)

# %% [markdown]
# (XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#         colsample_bytree=1, gamma=0, learning_rate=0.07, max_delta_step=0,
#         max_depth=4, min_child_weight=1, missing=None, n_estimators=200,
#         n_jobs=-1, nthread=None, objective='binary:logistic',
#         random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#         seed=42, silent=True, subsample=1, tree_method='gpu_exact'),
#
#  0.712043020651798)

# %%
from sklearn.linear_model import LogisticRegression

params= {
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'class_weight': [{0: 1, 1: 1}, #(equivalent to None)
{0: 1, 1: 2},
{0: 1, 1: 10}, #(roughly equivalent to 'balanced' for this dataset)
{0: 1, 1: 100},
{0: 1, 1: 10000}]

}

gridsearch = RandomizedSearchCV(
    LogisticRegression(n_jobs=-1), 
    param_distributions = params,
    scoring='roc_auc',
    n_iter = 10,
    cv=5,
    n_jobs = -1,
    verbose=10,
    random_state=42,
    return_train_score=True
)

gridsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.5min
# /home/nedderlander/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  3.0min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=-1,
#           penalty='l2', random_state=None, solver='warn', tol=0.0001,
#           verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=-1,
#           param_distributions={'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 2}, {0: 1, 1: 10}, {0: 1, 1: 100}, {0: 1, 1: 10000}]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score=True, scoring='roc_auc', verbose=10)

# %%
results = pd.DataFrame(gridsearch.cv_results_)
results.sort_values(by='rank_test_score').T

y_pred_proba = gridsearch.best_estimator_.predict_proba(X_test)[:,1]
test_roc = roc_auc_score(y_test, y_pred_proba)

gridsearch.best_estimator_, test_roc
# Out:
# (LogisticRegression(C=1.0, class_weight={0: 1, 1: 2}, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=-1, penalty='l2', random_state=None,
#            solver='newton-cg', tol=0.0001, verbose=0, warm_start=False),
#  0.7025240234214909)

# %% [markdown]
# (LogisticRegression(C=1.0, class_weight={0: 1, 1: 2}, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=-1, penalty='l2', random_state=None,
#            solver='newton-cg', tol=0.0001, verbose=0, warm_start=False),
#  0.7025240234214909)
